# %%
import pandas as pd

# %%
df_resultado_igovti = pd.read_excel('dados/resultado_igovti.xlsx')
df_respostas_igovti = pd.read_excel('dados/resposta_questionario_setic.xlsx')

# %%
for index, row in df.iterrows():
    orgao = row['attribute_1']
    print(f'Gerando para {orgao}')

    #Secao introdutoria

    #Secao resultados do iGovTI

    #Secao Achados de Auditoria

    #Secao encaminhamentos
# Out:
# Gerando para FAPERJ
# Gerando para SEAPPA
# Gerando para TURISRIO
# Gerando para ISP
# Gerando para SEFAZ
# Gerando para DETRO
# Gerando para CODERTE
# Gerando para FSC
# Gerando para SETD
# Gerando para SUDERJ
# Gerando para SETUR
# Gerando para CEHAB
# Gerando para SEELJE
# Gerando para CODIN
# Gerando para CASERJ
# Gerando para CGE
# Gerando para SERGB
# Gerando para SECTI
# Gerando para CENTRAL
# Gerando para IPEM/RJ
# Gerando para EMOP
# Gerando para CEPERJ
# Gerando para FUNARJ
# Gerando para FTMRJ
# Gerando para SES
# Gerando para DEGASE
# Gerando para SEDEC
# Gerando para SEAS
# Gerando para AGENERSA
# Gerando para DER/RJ
# Gerando para CEASA
# Gerando para RIOTRILH
# Gerando para SEGOV
# Gerando para SEDSODH
# Gerando para RJPREV
# Gerando para IRM
# Gerando para SECC
# Gerando para JUCERJA
# Gerando para IEEA
# Gerando para DETRAN
# Gerando para ITERJ
# Gerando para SEIC
# Gerando para SECEC
# Gerando para AGERIO
# Gerando para AGETRANSP
# Gerando para DRM
# ...
